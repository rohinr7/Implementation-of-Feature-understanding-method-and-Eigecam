# %%
from YOLOv8_Explainer import yolov8_heatmap, display_images

# %%
model = yolov8_heatmap(
    weight="best.pt",
    method="EigenGradCAM",
)
# Out:
# Model summary: 225 layers, 3011628 parameters, 0 gradients, 8.2 GFLOPs

# %%
imagelist = model(
    img_path=r"C:\Users\rohin\Desktop\New folder (2)\trdp\Fem_xai\pytorch_grad_cam\YOLOv8_Explainer-main\YOLOv8_Explainer-main\test_images\Frame_4680.png", 
    )

# %%
len(imagelist)
# Out:
# 1

# %%
display_images(imagelist)

# %%
# %pip install grad-cam==1.4.8
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
